# %%
# %matplotlib qt 
import SimpleITK as sitk
from scrollview import ScrollView
import numpy as np
import matplotlib.pyplot as plt
from IndexTracker import IndexTracker

# %%
# import the image and its segmentation for one patient
itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd')
image_array = sitk.GetArrayViewFromImage(itk_image)

# print the image's dimensions
print(image_array.shape)
aspect_ratio = [0.488281, 0.488281, 1] # Is the elementspacing in *.mhd files

itk_image_seg = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/prostaat.mhd')
segmentation = sitk.GetArrayViewFromImage(itk_image_seg)

# print the segmentation's dimensions
print(segmentation.shape)
# Out:
# (86, 333, 271)
# (86, 333, 271)

# %%
# show the image
fig, ax = plt.subplots(1, 2)
tracker1 = IndexTracker(ax[0], image_array);
tracker2 = IndexTracker(ax[1], segmentation)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker2.onscroll);

plt.show()

# %% [markdown]
# ## Registration of 5 images to target image

# %%
import elastix
import os

ELASTIX_PATH = 'C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe'
el = elastix.ElastixInterface(elastix_path=ELASTIX_PATH)

# %%
moving_img_1 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p107/mr_bffe.mhd'
moving_img_2 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p108/mr_bffe.mhd'
moving_img_3 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p115/mr_bffe.mhd'
moving_img_4 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p116/mr_bffe.mhd'
moving_img_5 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p117/mr_bffe.mhd'

fixed_img = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd'

rigid_param_file = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/Rigid - copia.txt'
bspline64_param_file = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/BSpline64.txt'

output_dir1 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1'

# %% [markdown]
# ### Rigid registration

# %%
el.register(
    fixed_image=fixed_img,
    moving_image=moving_img_1,
    parameters=[rigid_param_file],
    output_dir=output_dir1)

result_path = os.path.join(output_dir, 'result.0.tiff')
# Out:
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p107/mr_bffe.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/Rigid - copia.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1

# %%
rigid_param_file = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/Rigid - copia.txt'

output_dir2 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_img_2,
    parameters=[rigid_param_file],
    output_dir=output_dir2)

result_path = os.path.join(output_dir, 'result.0.tiff')

output_dir3 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_img_3,
    parameters=[rigid_param_file],
    output_dir=output_dir3)

result_path = os.path.join(output_dir, 'result.0.tiff')

output_dir4 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_img_4,
    parameters=[rigid_param_file],
    output_dir=output_dir4)

result_path = os.path.join(output_dir, 'result.0.tiff')

output_dir5 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_img_5,
    parameters=[rigid_param_file],
    output_dir=output_dir5)

result_path = os.path.join(output_dir, 'result.0.tiff')
# Out:
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p108/mr_bffe.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/Rigid - copia.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p115/mr_bffe.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/Rigid - copia.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3
# ...

# %% [markdown]
# **Visualize rigid registration results**

# %%
res1_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1/result.0.mhd')
res1_image_array = sitk.GetArrayViewFromImage(res1_itk_image)

res2_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2/result.0.mhd')
res2_image_array = sitk.GetArrayViewFromImage(res2_itk_image)

res3_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3/result.0.mhd')
res3_image_array = sitk.GetArrayViewFromImage(res3_itk_image)

res4_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4/result.0.mhd')
res4_image_array = sitk.GetArrayViewFromImage(res4_itk_image)

res5_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5/result.0.mhd')
res5_image_array = sitk.GetArrayViewFromImage(res5_itk_image)

fixed_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd')
fixed_image_array = sitk.GetArrayViewFromImage(fixed_itk_image)

# show the image
fig, ax = plt.subplots(1, 6)
tracker1 = IndexTracker(ax[0], res1_image_array);
tracker2 = IndexTracker(ax[1], res2_image_array)
tracker3 = IndexTracker(ax[2], res3_image_array)
tracker4 = IndexTracker(ax[3], res4_image_array)
tracker5 = IndexTracker(ax[4], res5_image_array)
tracker6 = IndexTracker(ax[5], fixed_image_array)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker2.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker3.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker4.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker5.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker6.onscroll);

plt.show()
# Out:
# down -1.0
# down -1.0
# down -1.0
# down -1.0
# down -1.0
# down -1.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 11.0
# up 11.0
# up 11.0
# up 11.0
# up 11.0
# up 11.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 6.0
# up 2.0
# up 2.0
# up 2.0
# up 2.0
# up 2.0
# up 2.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 1.0
# up 1.0
# up 1.0
# up 1.0
# up 1.0
# up 1.0
# up 4.0
# up 4.0
# up 4.0
# up 4.0
# up 4.0
# up 4.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 3.0
# up 5.0
# up 5.0
# up 5.0
# up 5.0
# up 5.0
# up 5.0
# up 8.0
# up 8.0
# up 8.0
# up 8.0
# up 8.0
# up 8.0
# down -5.0
# down -5.0
# down -5.0
# down -5.0
# down -5.0
# down -5.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# down -7.0
# down -8.0
# down -8.0
# down -8.0
# down -8.0
# ...

# %% [markdown]
# ### B-spline registration to rigid registered image

# %%
moving_image_1b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1/result.0.mhd'
output_dir_1b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1b'


el.register(
    fixed_image=fixed_img,
    moving_image=moving_image_1b,
    parameters=[bspline64_param_file],
    output_dir=output_dir_1b)

result_path = os.path.join(output_dir, 'result.0.tiff')
# Out:
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1/result.0.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/BSpline64.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1b

# %%
moving_image_2b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2/result.0.mhd'
output_dir2b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2b'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_image_2b,
    parameters=[bspline64_param_file],
    output_dir=output_dir2b)

result_path = os.path.join(output_dir, 'result.0.tiff')

moving_image_3b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3/result.0.mhd'
output_dir3b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3b'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_image_3b,
    parameters=[bspline64_param_file],
    output_dir=output_dir3b)

result_path = os.path.join(output_dir, 'result.0.tiff')

moving_image_4b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4/result.0.mhd'
output_dir4b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4b'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_image_4b,
    parameters=[bspline64_param_file],
    output_dir=output_dir4b)

result_path = os.path.join(output_dir, 'result.0.tiff')

moving_image_5b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5/result.0.mhd'
output_dir5b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5b'

el.register(
    fixed_image=fixed_img,
    moving_image=moving_image_5b,
    parameters=[bspline64_param_file],
    output_dir=output_dir5b)

result_path = os.path.join(output_dir, 'result.0.tiff')
# Out:
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2/result.0.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/BSpline64.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2b
# C:/Users/Paula Arias/elastix-5.0.1-win64/elastix.exe -f C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd -m C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3/result.0.mhd -p C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/ParameterFiles/BSpline64.txt -out C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3b
# ...

# %% [markdown]
# **Visualize rigid+b-spline registration results**

# %%
res1b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1b/result.0.mhd')
res1b_image_array = sitk.GetArrayViewFromImage(res1b_itk_image)

res2b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2b/result.0.mhd')
res2b_image_array = sitk.GetArrayViewFromImage(res2b_itk_image)

res3b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3b/result.0.mhd')
res3b_image_array = sitk.GetArrayViewFromImage(res3b_itk_image)

res4b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4b/result.0.mhd')
res4b_image_array = sitk.GetArrayViewFromImage(res4b_itk_image)

res5b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5b/result.0.mhd')
res5b_image_array = sitk.GetArrayViewFromImage(res5b_itk_image)

fixed_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/mr_bffe.mhd')
fixed_image_array = sitk.GetArrayViewFromImage(fixed_itk_image)

# show the image
fig, ax = plt.subplots(1, 6)
tracker1 = IndexTracker(ax[0], res1b_image_array);
tracker2 = IndexTracker(ax[1], res2b_image_array)
tracker3 = IndexTracker(ax[2], res3b_image_array)
tracker4 = IndexTracker(ax[3], res4b_image_array)
tracker5 = IndexTracker(ax[4], res5b_image_array)
tracker6 = IndexTracker(ax[5], fixed_image_array)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker2.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker3.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker4.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker5.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker6.onscroll);

plt.show()

# %% [markdown]
# ## Apply transformations to prostate segmentations

# %%
TRANSFORMIX_PATH = 'C:/Users/Paula Arias/elastix-5.0.1-win64/transformix.exe'

# %%
#seg1_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p107/prostaat.mhd')
#seg1_image_array = sitk.GetArrayViewFromImage(seg1_itk_image)
#
#seg1_image_array = seg1_image_array.astype(float)
#
#sitk.WriteImage(seg1_itk_image, 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/floats/seg1.mhd')
#sitk.WriteImage(seg1_image_array, 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/floats/seg1.raw')

# %% [markdown]
# **Apply rigid transform to masks**

# %%
seg1 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p107/prostaat.mhd'
output_dir_seg1 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg1'
transformation_params1 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1/TransformParameters.0.txt'

tr1 = elastix.TransformixInterface(parameters=transformation_params1, transformix_path=TRANSFORMIX_PATH)

transformed_image_path1 = tr1.transform_image(seg1, output_dir=output_dir_seg1)

# %%
seg2 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p108/prostaat.mhd'
output_dir_seg2 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg2'
transformation_params2 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try2/TransformParameters.0.txt'

tr2 = elastix.TransformixInterface(parameters=transformation_params2, transformix_path=TRANSFORMIX_PATH)
transformed_image_path2 = tr2.transform_image(seg2, output_dir=output_dir_seg2)

seg3 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p115/prostaat.mhd'
output_dir_seg3 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg3'
transformation_params3 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try3/TransformParameters.0.txt'

tr3 = elastix.TransformixInterface(parameters=transformation_params3, transformix_path=TRANSFORMIX_PATH)
transformed_image_path3 = tr3.transform_image(seg3, output_dir=output_dir_seg3)

seg4 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p116/prostaat.mhd'
output_dir_seg4 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg4'
transformation_params4 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try4/TransformParameters.0.txt'

tr4 = elastix.TransformixInterface(parameters=transformation_params4, transformix_path=TRANSFORMIX_PATH)
transformed_image_path4 = tr4.transform_image(seg4, output_dir=output_dir_seg4)

seg5 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p117/prostaat.mhd'
output_dir_seg5 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg5'
transformation_params5 = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try5/TransformParameters.0.txt'

tr5 = elastix.TransformixInterface(parameters=transformation_params5, transformix_path=TRANSFORMIX_PATH)
transformed_image_path5 = tr5.transform_image(seg5, output_dir=output_dir_seg5)

# %%
seg1_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg1/result.mhd')
seg1_image_array = sitk.GetArrayViewFromImage(seg1_itk_image)

seg2_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg2/result.mhd')
seg2_image_array = sitk.GetArrayViewFromImage(seg2_itk_image)

seg3_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg3/result.mhd')
seg3_image_array = sitk.GetArrayViewFromImage(seg3_itk_image)

seg4_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg4/result.mhd')
seg4_image_array = sitk.GetArrayViewFromImage(seg4_itk_image)

seg5_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg5/result.mhd')
seg5_image_array = sitk.GetArrayViewFromImage(seg5_itk_image)

fixed_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/prostaat.mhd')
fixed_image_array = sitk.GetArrayViewFromImage(fixed_itk_image)

# show the image
fig, ax = plt.subplots(1, 6)
tracker1 = IndexTracker(ax[0], seg1_image_array);
tracker2 = IndexTracker(ax[1], seg2_image_array)
tracker3 = IndexTracker(ax[2], seg3_image_array)
tracker4 = IndexTracker(ax[3], seg4_image_array)
tracker5 = IndexTracker(ax[4], seg5_image_array)
tracker6 = IndexTracker(ax[5], fixed_image_array)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker2.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker3.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker4.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker5.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker6.onscroll);

plt.show()
# Out:
# up 5.266666666666667
# up 5.266666666666667
# up 5.266666666666667
# up 5.266666666666667
# up 5.266666666666667
# up 5.266666666666667
# up 24.766666666666666
# up 24.766666666666666
# up 24.766666666666666
# up 24.766666666666666
# up 24.766666666666666
# up 24.766666666666666
# down -22.933333333333334
# down -22.933333333333334
# down -22.933333333333334
# down -22.933333333333334
# down -22.933333333333334
# down -22.933333333333334

# %% [markdown]
# **B-spline transform to previous result**

# %%
seg1b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg1/result.mhd'
output_dir_seg1b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg1b'
transformation_params1b = 'C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/try1b/TransformParameters.0.txt'

tr1b = elastix.TransformixInterface(parameters=transformation_params1b, transformix_path=TRANSFORMIX_PATH)
transformed_image_path1b = tr1b.transform_image(seg1b, output_dir=output_dir_seg1b)

# %%
seg1b_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/RESULTS/seg1b/result.mhd')
seg1b_image_array = sitk.GetArrayViewFromImage(seg1b_itk_image)

fixed_itk_image = sitk.ReadImage('C:/Users/Paula Arias/Escritorio/CAPITASELECTA_Project/TrainingData/p102/prostaat.mhd')
fixed_image_array = sitk.GetArrayViewFromImage(fixed_itk_image)

# show the image
fig, ax = plt.subplots(1, 2)
tracker1 = IndexTracker(ax[0], seg1_image_array);
tracker2 = IndexTracker(ax[1], fixed_image_array)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll);
fig.canvas.mpl_connect('scroll_event', tracker2.onscroll);

plt.show()
# Out:
# up 1.3666666666666667
# up 1.3666666666666667
# up 6.933333333333334
# up 6.933333333333334
# up 21.266666666666666
# up 21.266666666666666
# up 4.666666666666667
# up 4.666666666666667
# up 2.45
# up 2.45
# up 12.533333333333333
# up 12.533333333333333
# up 1.4333333333333333
# up 1.4333333333333333
# up 0.9666666666666667
# up 0.9666666666666667
# up 0.15
# up 0.15
# down -29.158333333333335
# down -29.158333333333335
# down -8.333333333333334
# down -8.333333333333334
# down -10.766666666666667
# down -10.766666666666667
# down -0.03333333333333333
# down -0.03333333333333333
# down -2.2333333333333334
# down -2.2333333333333334
# down -8.066666666666666
# down -8.066666666666666
# down -1.3333333333333333
# down -1.3333333333333333
# down -0.675
# down -0.675
# down -0.075
# down -0.075
# up 0.6333333333333333
# up 0.6333333333333333
# up 2.2
# up 2.2
# up 0.36666666666666664
# up 0.36666666666666664
# down -0.3333333333333333
# down -0.3333333333333333
# down -3.2
# down -3.2
# ...
